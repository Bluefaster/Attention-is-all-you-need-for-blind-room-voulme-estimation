# %% [markdown]
# # Audio convolution
#
# Processing anechoic speech by convolutions with RIRs to generate reverberrant speech examples, passing those speech examples through our featurization pipeline

# %%
import numpy as np
import librosa as lr
from librosa import display, feature
import pandas as pd
import soundfile as sf
import os
import matplotlib.pyplot as plt
import glob as glob
from tqdm import tqdm
from IPython.display import Audio
from scipy.signal import convolve
import pickle

# %%
speech_dir = "/home/cxw/sonos_rirs/voice_ace/Speech"

speech_files = np.sort(glob.glob(speech_dir+"/*.wav"))

target_rate = 16000

# %%
lengths = []
for file in tqdm(speech_files):
    y, sr = lr.load(file)
    lengths.append(len(y)/sr)
    
_=plt.hist(lengths, bins=10)
# Out:
# 100%|███████████████████████████████████████████| 58/58 [00:29<00:00,  1.99it/s]

# %%
speech_df = pd.DataFrame(speech_files, columns=['file'])
speech_df['length (s)'] = lengths
speech_sample = speech_df.sample(10)
# speech_df.to_csv('/home/cxw/volest/volume-estimation/data/ace_speech.csv', index=False)

# %%
speech_df = pd.read_csv('/home/cxw/volest/volume-estimation/data/ace_speech.csv')
rir_df = pd.read_csv('/home/cxw/volest/volume-estimation/data/0803_rir_df.csv')

# %%
n_rooms = rir_df.nunique(axis=0)['room']
n_samples = 2000
n_per_room = (n_samples//n_rooms) + 1
print(n_per_room)
# Out:
# 28

# %%
rir_sample = rir_df.groupby('room').sample(n=n_per_room, replace=True)
rir_sample['vol'].apply(np.log10).hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
rir, sr_rir = lr.load(rir_sample.iloc[9]['file'], sr=target_rate)
speech, sr_speech = lr.load(speech_sample.iloc[0]['file'], sr=target_rate)

# %%
#computer power of speech signal

def get_power(y):
    rms = lr.feature.rms(y=y)
    power = np.average(rms)**2
    return power

signal_power = get_power(speech)
print(signal_power)

noise = np.random.normal(size=len(speech))
noise_power = get_power(noise)
print(noise_power)

snr = 30 #in db
noise_ratio = signal_power / np.exp(snr/20)
print(noise_ratio)

noise_scaled = noise*np.sqrt(noise_ratio)
print(get_power(noise_scaled))

noisy_speech = speech + noise_scaled
Audio(data=noisy_speech, rate=target_rate)
# Out:
# 0.0002897920709108437
# 0.9954307673764513
# 6.466135119208169e-05
# 6.436589843673209e-05
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def conv_signals(speech, rir, snr=np.infty, noise=None):
    if noise == None:
        noise = np.random.normal(size=len(speech))
    noise_ratio = get_power(speech) / np.exp(snr/20)
    noise_scaled = noise * np.sqrt(noise_ratio)
    
    speech_signal = convolve(speech, rir, mode='same')
    noise_signal = convolve(noise_scaled, rir, mode='same')
    out_signal = speech_signal + noise_signal
    out_signal = out_signal / np.max(out_signal.flatten())
    return out_signal

def window_audio(speech, n_samples):
    offset_max = len(speech) - (n_samples+1)
    offset = np.random.randint(0, offset_max)
    return speech[offset:offset+n_samples]

# %%
sr = 22050
def generate_rir_audio(n_samples, speech_df, rir_sample, len_clip=4, sr=22050, return_audio=True,\
                       snr_list=[np.infty], verbose=False, out_path=None):
    #len_clip - length of clip in seconds
    valid_speech = speech_df[speech_df['length (s)']>=len_clip]
    speech_sample = valid_speech.sample(n_samples, replace=True).reset_index()
        
    sample_df = speech_sample.join(rir_sample, lsuffix='_speech', rsuffix='_rir')
    audio_clips = []
    
    output_df_list = []
    for row in tqdm(sample_df.iterrows()):
        speech, _ = lr.load(row[1]['file_speech'], sr=sr)
        rir, _ = lr.load(row[1]['file_rir'], sr=sr)
        windowed_speech = window_audio(speech, len_clip*sr)
        for snr in snr_list:
            out_row = row[1].copy()
            out_row['snr'] = snr
            conv_audio = conv_signals(windowed_speech, rir, snr=snr)
            if snr is np.infty:
                snr_tag = "snr_clean"
            else:
                snr_tag = "snr_{}db".format(snr)
            clipname = "clip{}_{}".format(row[0],snr_tag)
            out_row['clip_label'] = clipname
            if return_audio:
                audio_clips.append(conv_audio)
            if out_path is not None:
                file = os.path.join(out_path, '{}.wav'.format(clipname))
                out_row['file_clip'] = file
                sf.write(file, conv_audio, sr)
                if verbose:
                    print("Saved file to {}".format(file))
            output_df_list.append(out_row)
 
    out_df = pd.DataFrame(output_df_list).reset_index().drop(columns=['index'])
    df_path = os.path.join(out_path,'audio_df.csv')
    out_df.to_csv(df_path, index=False)
    print("Results stored to {}".format(df_path))
    if return_audio:
        return out_df, audio_clips
    else:
        return out_df

    

    
sample_df, audio_clips = generate_rir_audio(10, speech_df, rir_df, sr=sr, snr_list=[np.infty, 20, 10, 0],\
                                            verbose=False, out_path='/home/cxw/sonos_rirs/reverb_audio/testrun')
# Out:
# 10it [00:07,  1.35it/s]
# Results stored to /home/cxw/sonos_rirs/reverb_audio/testrun/audio_df.csv

# %%
# AUDIO_PATH = '/home/cxw/sonos_rirs/reverb_audio'
# audioset_name = '080322_10K'

# generate_rir_audio(n_samples, speech_df, rir_sample, sr=sr, snr_list=[np.infty, 20, 10, 0],\
#                                             verbose=False, out_path='/home/cxw/sonos_rirs/reverb_audio/testrun')

# %%
sample_df
# Out:
#     index_speech                                     file_speech  length (s)  \
# 0             18  /home/cxw/sonos_rirs/voice_ace/Speech/F4s4.wav   35.924853
# 1             18  /home/cxw/sonos_rirs/voice_ace/Speech/F4s4.wav   35.924853
# 2             18  /home/cxw/sonos_rirs/voice_ace/Speech/F4s4.wav   35.924853
# 3             18  /home/cxw/sonos_rirs/voice_ace/Speech/F4s4.wav   35.924853
# 4             42  /home/cxw/sonos_rirs/voice_ace/Speech/M4s3.wav    7.553696
# 5             42  /home/cxw/sonos_rirs/voice_ace/Speech/M4s3.wav    7.553696
# 6             42  /home/cxw/sonos_rirs/voice_ace/Speech/M4s3.wav    7.553696
# 7             42  /home/cxw/sonos_rirs/voice_ace/Speech/M4s3.wav    7.553696
# 8             34  /home/cxw/sonos_rirs/voice_ace/Speech/M2s5.wav   12.922948
# 9             34  /home/cxw/sonos_rirs/voice_ace/Speech/M2s5.wav   12.922948
# 10            34  /home/cxw/sonos_rirs/voice_ace/Speech/M2s5.wav   12.922948
# 11            34  /home/cxw/sonos_rirs/voice_ace/Speech/M2s5.wav   12.922948
# 12            52  /home/cxw/sonos_rirs/voice_ace/Speech/M7s3.wav   10.534104
# 11        ace_Office_1     ace   47.3   0.0    clip2_snr_0db
# 12        ace_Office_1     ace   47.3   inf  clip3_snr_clean
# 13        ace_Office_1     ace   47.3  20.0   clip3_snr_20db
# 14        ace_Office_1     ace   47.3  10.0   clip3_snr_10db
# 15        ace_Office_1     ace   47.3   0.0    clip3_snr_0db
# 16  ace_Building_Lobby     ace   72.9   inf  clip4_snr_clean
# 17  ace_Building_Lobby     ace   72.9  20.0   clip4_snr_20db
# 18  ace_Building_Lobby     ace   72.9  10.0   clip4_snr_10db
# 19  ace_Building_Lobby     ace   72.9   0.0    clip4_snr_0db
# 20  ace_Building_Lobby     ace   72.9   inf  clip5_snr_clean
# 21  ace_Building_Lobby     ace   72.9  20.0   clip5_snr_20db
# 22  ace_Building_Lobby     ace   72.9  10.0   clip5_snr_10db
# 23  ace_Building_Lobby     ace   72.9   0.0    clip5_snr_0db
# 24  ace_Meeting_Room_1     ace   99.6   inf  clip6_snr_clean
# 25  ace_Meeting_Room_1     ace   99.6  20.0   clip6_snr_20db
# 26  ace_Meeting_Room_1     ace   99.6  10.0   clip6_snr_10db
# 27  ace_Meeting_Room_1     ace   99.6   0.0    clip6_snr_0db
# 28  ace_Meeting_Room_1     ace   99.6   inf  clip7_snr_clean
# 29  ace_Meeting_Room_1     ace   99.6  20.0   clip7_snr_20db
# 30  ace_Meeting_Room_1     ace   99.6  10.0   clip7_snr_10db
# 31  ace_Meeting_Room_1     ace   99.6   0.0    clip7_snr_0db
# 32  ace_Meeting_Room_2     ace  246.0   inf  clip8_snr_clean
# 33  ace_Meeting_Room_2     ace  246.0  20.0   clip8_snr_20db
# 34  ace_Meeting_Room_2     ace  246.0  10.0   clip8_snr_10db
# 35  ace_Meeting_Room_2     ace  246.0   0.0    clip8_snr_0db
# 36  ace_Meeting_Room_2     ace  246.0   inf  clip9_snr_clean
# 37  ace_Meeting_Room_2     ace  246.0  20.0   clip9_snr_20db
# 38  ace_Meeting_Room_2     ace  246.0  10.0   clip9_snr_10db
# 39  ace_Meeting_Room_2     ace  246.0   0.0    clip9_snr_0db
#
#                                             file_clip
# 0   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 1   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 2   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 3   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 4   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 5   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 6   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 7   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 8   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 9   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 10  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 11  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 12  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 13  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 14  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 15  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 16  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 17  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 18  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 19  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 20  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 21  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 22  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 23  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 24  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 25  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 26  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 27  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 28  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 29  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 30  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 31  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 32  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 33  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 34  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 35  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 36  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 37  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 38  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 39  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...

# %%
Audio(filename='/home/cxw/sonos_rirs/reverb_audio/testrun/clip5_snr_clean.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(filename='/home/cxw/sonos_rirs/reverb_audio/testrun/clip5_snr_20db.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(filename='/home/cxw/sonos_rirs/reverb_audio/testrun/clip5_snr_10db.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(filename='/home/cxw/sonos_rirs/reverb_audio/testrun/clip5_snr_0db.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import volume_estimation.featurization as feat

# %%
path_audio = '/home/cxw/sonos_rirs/reverb_audio/testrun/clip0_snr_clean.wav'
y, sr= lr.load(path_audio, sr=sr)
n_samples = len(y)

# %%
gt_f = feat.gammatone_feat(n_samples)
dft_f = feat.dft_feat(n_samples, out_len=gt_f.out_shape[1])
dfts_f = feat.dft_feat(n_samples, is_sorted=True, out_len=gt_f.out_shape[1])
cepstrum_f = feat.cepstrum_feat(n_samples, out_len=gt_f.out_shape[1]) 
rms_f = feat.envelope_feat(n_samples, out_len=gt_f.out_shape[1])

feats = [gt_f, dft_f, dfts_f, cepstrum_f, rms_f]
block_f = feat.featurizer_block(n_samples, featurizations=feats, out_len=gt_f.out_shape[1])
# Out:
# Gammatone output shape: (20, 2755)
# Dft output shape: (1, 2755)
# Dft output shape: (1, 2755)
# Ceptrum output shape: (1, 2755)
# Envelope output shape: (1, 2755)
# Featurization block output shape: (24, 2755)
# /home/cxw/volest/volume-estimation/volume_estimation/featurization.py:160: RuntimeWarning: divide by zero encountered in log
#   log_spec_amp = np.log(np.power(np.abs(dft),2))
# /home/cxw/volest/volume-estimation/volume_estimation/featurization.py:56: RuntimeWarning: invalid value encountered in true_divide
#   feature = feature/max(feature.flatten())

# %%
test_feat = block_f.process(y)
lr.display.specshow(test_feat)
print(test_feat.shape)
plt.colorbar()
# Out:
# (24, 2755)
# /home/cxw/anaconda3/envs/cxwnotebook/lib/python3.8/site-packages/librosa/util/decorators.py:88: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   return f(*args, **kwargs)

# %%
output_dir = '/home/cxw/sonos_rirs/features/testrun'

# %%
def process_features(pairs_df, featurizer, output_dir, sr=16000, verbose=False,\
                     return_features=False):
    features = []
    volumes = []
    
    featurizer_path = os.path.join(output_dir, 'featurizer.pickle')
    
    with open(featurizer_path, 'wb') as f:
        pickle.dump(featurizer, f)
        
    if verbose:
        print("Saved featurizer to {}".format(featurizer_path))
        
    feat_files = []    
    for row in tqdm(pairs_df.iterrows()):
        row_tup = row[1]
        label = row_tup['clip_label']
        audio, _ = lr.load(row_tup['file_clip'], sr=sr)
        feature = featurizer.process(audio)
        
        filename = os.path.join(output_dir, label + '.npz')
        np.savez(filename, feat=feature, vol=row_tup['vol'])
        feat_files.append(filename)
        if verbose:
            print("Saved feature to {}".format(filename))
        
        if return_features:
            features.append(feature)
            volumes.append(row_tup['vol'])
    pairs_df['file_feature'] = feat_files
    df_path = os.path.join(output_dir, 'feature_df.csv')
    pairs_df.to_csv(df_path, index=False)
    print("Saved to {}".format(df_path))
    if return_features:
        return pairs_df, zip(features, volumes)
    else:
        return pairs_df

# %%
feat_df = process_features(sample_df, block_f, output_dir, sr=sr)
# Out:
# 40it [00:02, 15.75it/s]
# Saved to /home/cxw/sonos_rirs/features/testrun/feature_df.csv

# %%
feat_df
# Out:
#     index_speech                                     file_speech  length (s)  \
# 0             18  /home/cxw/sonos_rirs/voice_ace/Speech/F4s4.wav   35.924853
# 1             18  /home/cxw/sonos_rirs/voice_ace/Speech/F4s4.wav   35.924853
# 2             18  /home/cxw/sonos_rirs/voice_ace/Speech/F4s4.wav   35.924853
# 3             18  /home/cxw/sonos_rirs/voice_ace/Speech/F4s4.wav   35.924853
# 4             42  /home/cxw/sonos_rirs/voice_ace/Speech/M4s3.wav    7.553696
# 5             42  /home/cxw/sonos_rirs/voice_ace/Speech/M4s3.wav    7.553696
# 6             42  /home/cxw/sonos_rirs/voice_ace/Speech/M4s3.wav    7.553696
# 7             42  /home/cxw/sonos_rirs/voice_ace/Speech/M4s3.wav    7.553696
# 8             34  /home/cxw/sonos_rirs/voice_ace/Speech/M2s5.wav   12.922948
# 9             34  /home/cxw/sonos_rirs/voice_ace/Speech/M2s5.wav   12.922948
# 10            34  /home/cxw/sonos_rirs/voice_ace/Speech/M2s5.wav   12.922948
# 11            34  /home/cxw/sonos_rirs/voice_ace/Speech/M2s5.wav   12.922948
# 12            52  /home/cxw/sonos_rirs/voice_ace/Speech/M7s3.wav   10.534104
# 13            52  /home/cxw/sonos_rirs/voice_ace/Speech/M7s3.wav   10.534104
# 14            52  /home/cxw/sonos_rirs/voice_ace/Speech/M7s3.wav   10.534104
# 15            52  /home/cxw/sonos_rirs/voice_ace/Speech/M7s3.wav   10.534104
# 16            47  /home/cxw/sonos_rirs/voice_ace/Speech/M5s3.wav   12.319501
# 17            47  /home/cxw/sonos_rirs/voice_ace/Speech/M5s3.wav   12.319501
# 18            47  /home/cxw/sonos_rirs/voice_ace/Speech/M5s3.wav   12.319501
# 19            47  /home/cxw/sonos_rirs/voice_ace/Speech/M5s3.wav   12.319501
# 20            38  /home/cxw/sonos_rirs/voice_ace/Speech/M3s4.wav   78.634286
# 21            38  /home/cxw/sonos_rirs/voice_ace/Speech/M3s4.wav   78.634286
# 22            38  /home/cxw/sonos_rirs/voice_ace/Speech/M3s4.wav   78.634286
# 23            38  /home/cxw/sonos_rirs/voice_ace/Speech/M3s4.wav   78.634286
# 24            17  /home/cxw/sonos_rirs/voice_ace/Speech/F4s3.wav   10.814921
# 25            17  /home/cxw/sonos_rirs/voice_ace/Speech/F4s3.wav   10.814921
# 26            17  /home/cxw/sonos_rirs/voice_ace/Speech/F4s3.wav   10.814921
# 27            17  /home/cxw/sonos_rirs/voice_ace/Speech/F4s3.wav   10.814921
# 28            14  /home/cxw/sonos_rirs/voice_ace/Speech/F3s5.wav   12.677007
# 29            14  /home/cxw/sonos_rirs/voice_ace/Speech/F3s5.wav   12.677007
# 30            14  /home/cxw/sonos_rirs/voice_ace/Speech/F3s5.wav   12.677007
# 31            14  /home/cxw/sonos_rirs/voice_ace/Speech/F3s5.wav   12.677007
# 32            22  /home/cxw/sonos_rirs/voice_ace/Speech/F5s3.wav    5.170340
# 33            22  /home/cxw/sonos_rirs/voice_ace/Speech/F5s3.wav    5.170340
# 34            22  /home/cxw/sonos_rirs/voice_ace/Speech/F5s3.wav    5.170340
# 35            22  /home/cxw/sonos_rirs/voice_ace/Speech/F5s3.wav    5.170340
# 36            53  /home/cxw/sonos_rirs/voice_ace/Speech/M7s4.wav   76.174694
# 37            53  /home/cxw/sonos_rirs/voice_ace/Speech/M7s4.wav   76.174694
# 38            53  /home/cxw/sonos_rirs/voice_ace/Speech/M7s4.wav   76.174694
# 39            53  /home/cxw/sonos_rirs/voice_ace/Speech/M7s4.wav   76.174694
#
#     index_rir                                           file_rir  \
# 0           0  /home/cxw/sonos_rirs/rirs/ace/Single/Office_2/...
# 1           0  /home/cxw/sonos_rirs/rirs/ace/Single/Office_2/...
# 2           0  /home/cxw/sonos_rirs/rirs/ace/Single/Office_2/...
# 3           0  /home/cxw/sonos_rirs/rirs/ace/Single/Office_2/...
# 4           1  /home/cxw/sonos_rirs/rirs/ace/Single/Office_2/...
# 5           1  /home/cxw/sonos_rirs/rirs/ace/Single/Office_2/...
# 6           1  /home/cxw/sonos_rirs/rirs/ace/Single/Office_2/...
# 7           1  /home/cxw/sonos_rirs/rirs/ace/Single/Office_2/...
# 9         ace_Office_1     ace   47.3  20.0   clip2_snr_20db
# 10        ace_Office_1     ace   47.3  10.0   clip2_snr_10db
# 11        ace_Office_1     ace   47.3   0.0    clip2_snr_0db
# 12        ace_Office_1     ace   47.3   inf  clip3_snr_clean
# 13        ace_Office_1     ace   47.3  20.0   clip3_snr_20db
# 14        ace_Office_1     ace   47.3  10.0   clip3_snr_10db
# 15        ace_Office_1     ace   47.3   0.0    clip3_snr_0db
# 16  ace_Building_Lobby     ace   72.9   inf  clip4_snr_clean
# 17  ace_Building_Lobby     ace   72.9  20.0   clip4_snr_20db
# 18  ace_Building_Lobby     ace   72.9  10.0   clip4_snr_10db
# 19  ace_Building_Lobby     ace   72.9   0.0    clip4_snr_0db
# 20  ace_Building_Lobby     ace   72.9   inf  clip5_snr_clean
# 21  ace_Building_Lobby     ace   72.9  20.0   clip5_snr_20db
# 22  ace_Building_Lobby     ace   72.9  10.0   clip5_snr_10db
# 23  ace_Building_Lobby     ace   72.9   0.0    clip5_snr_0db
# 24  ace_Meeting_Room_1     ace   99.6   inf  clip6_snr_clean
# 25  ace_Meeting_Room_1     ace   99.6  20.0   clip6_snr_20db
# 26  ace_Meeting_Room_1     ace   99.6  10.0   clip6_snr_10db
# 27  ace_Meeting_Room_1     ace   99.6   0.0    clip6_snr_0db
# 28  ace_Meeting_Room_1     ace   99.6   inf  clip7_snr_clean
# 29  ace_Meeting_Room_1     ace   99.6  20.0   clip7_snr_20db
# 30  ace_Meeting_Room_1     ace   99.6  10.0   clip7_snr_10db
# 31  ace_Meeting_Room_1     ace   99.6   0.0    clip7_snr_0db
# 32  ace_Meeting_Room_2     ace  246.0   inf  clip8_snr_clean
# 33  ace_Meeting_Room_2     ace  246.0  20.0   clip8_snr_20db
# 34  ace_Meeting_Room_2     ace  246.0  10.0   clip8_snr_10db
# 35  ace_Meeting_Room_2     ace  246.0   0.0    clip8_snr_0db
# 36  ace_Meeting_Room_2     ace  246.0   inf  clip9_snr_clean
# 37  ace_Meeting_Room_2     ace  246.0  20.0   clip9_snr_20db
# 38  ace_Meeting_Room_2     ace  246.0  10.0   clip9_snr_10db
# 39  ace_Meeting_Room_2     ace  246.0   0.0    clip9_snr_0db
#
#                                             file_clip  \
# 0   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 1   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 2   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 3   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 4   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 5   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 6   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 7   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 8   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 9   /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 10  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 11  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 12  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 13  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 14  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 15  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 16  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 17  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 18  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 19  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 20  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 21  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 22  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 23  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 24  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 25  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 26  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 27  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 28  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 29  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 30  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 31  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 32  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 33  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 34  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 35  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 36  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 37  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 38  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
# 39  /home/cxw/sonos_rirs/reverb_audio/testrun/clip...
#
#                                          file_feature
# 0   /home/cxw/sonos_rirs/features/testrun/clip0_sn...
# 1   /home/cxw/sonos_rirs/features/testrun/clip0_sn...
# 2   /home/cxw/sonos_rirs/features/testrun/clip0_sn...
# 3   /home/cxw/sonos_rirs/features/testrun/clip0_sn...
# 4   /home/cxw/sonos_rirs/features/testrun/clip1_sn...
# 5   /home/cxw/sonos_rirs/features/testrun/clip1_sn...
# 6   /home/cxw/sonos_rirs/features/testrun/clip1_sn...
# 7   /home/cxw/sonos_rirs/features/testrun/clip1_sn...
# 8   /home/cxw/sonos_rirs/features/testrun/clip2_sn...
# 9   /home/cxw/sonos_rirs/features/testrun/clip2_sn...
# 10  /home/cxw/sonos_rirs/features/testrun/clip2_sn...
# 11  /home/cxw/sonos_rirs/features/testrun/clip2_sn...
# 12  /home/cxw/sonos_rirs/features/testrun/clip3_sn...
# 13  /home/cxw/sonos_rirs/features/testrun/clip3_sn...
# 14  /home/cxw/sonos_rirs/features/testrun/clip3_sn...
# 15  /home/cxw/sonos_rirs/features/testrun/clip3_sn...
# 16  /home/cxw/sonos_rirs/features/testrun/clip4_sn...
# 17  /home/cxw/sonos_rirs/features/testrun/clip4_sn...
# 18  /home/cxw/sonos_rirs/features/testrun/clip4_sn...
# 19  /home/cxw/sonos_rirs/features/testrun/clip4_sn...
# 20  /home/cxw/sonos_rirs/features/testrun/clip5_sn...
# 21  /home/cxw/sonos_rirs/features/testrun/clip5_sn...
# 22  /home/cxw/sonos_rirs/features/testrun/clip5_sn...
# 23  /home/cxw/sonos_rirs/features/testrun/clip5_sn...
# 24  /home/cxw/sonos_rirs/features/testrun/clip6_sn...
# 25  /home/cxw/sonos_rirs/features/testrun/clip6_sn...
# 26  /home/cxw/sonos_rirs/features/testrun/clip6_sn...
# 27  /home/cxw/sonos_rirs/features/testrun/clip6_sn...
# 28  /home/cxw/sonos_rirs/features/testrun/clip7_sn...
# 29  /home/cxw/sonos_rirs/features/testrun/clip7_sn...
# 30  /home/cxw/sonos_rirs/features/testrun/clip7_sn...
# 31  /home/cxw/sonos_rirs/features/testrun/clip7_sn...
# 32  /home/cxw/sonos_rirs/features/testrun/clip8_sn...
# 33  /home/cxw/sonos_rirs/features/testrun/clip8_sn...
# 34  /home/cxw/sonos_rirs/features/testrun/clip8_sn...
# 35  /home/cxw/sonos_rirs/features/testrun/clip8_sn...
# 36  /home/cxw/sonos_rirs/features/testrun/clip9_sn...
# 37  /home/cxw/sonos_rirs/features/testrun/clip9_sn...
# 38  /home/cxw/sonos_rirs/features/testrun/clip9_sn...
# 39  /home/cxw/sonos_rirs/features/testrun/clip9_sn...

# %%
testpath = '/home/cxw/sonos_rirs/features/testrun/clip5_snr_10db.npz'
testload = np.load(testpath)

# %%
print(testload['feat'], '\n', testload['vol'])
# Out:
# [[ 1.18049463e-04+0.j          2.27314906e-04+0.j
#    9.67763634e-04+0.j         ...  1.50592461e-04+0.j
#    2.88832321e-04+0.j          5.04763782e-04+0.j        ]
#  [ 9.73802204e-05+0.j          8.20308456e-04+0.j
#    1.34986978e-03+0.j         ...  6.75669427e-04+0.j
#    3.88396547e-04+0.j          4.85993922e-04+0.j        ]
#  [ 3.54682463e-04+0.j          1.02150628e-03+0.j
#    2.31269364e-03+0.j         ...  5.95028160e-04+0.j
#    5.62339749e-04+0.j          5.56505845e-04+0.j        ]
#  ...
#  [-7.39080250e-01-0.3073796j  -6.08715475e-01-0.08115693j
#   -4.58495319e-01+0.41961715j ...  6.57414496e-01+0.07766649j
#    7.35611796e-01-0.24316858j  1.00000000e+00+0.j        ]
#  [ 1.00000000e+00+0.j          4.64649759e-02+0.j
#    1.22016650e-02+0.j         ...  2.83339410e-03+0.j
#    1.22016650e-02+0.j          4.64649759e-02+0.j        ]
#  [ 9.41437483e-02+0.j          1.35418609e-01+0.j
#    1.54968306e-01+0.j         ...  6.02684962e-03+0.j
#    5.27687604e-03+0.j          5.62786637e-03+0.j        ]]
#  72.9

# %%
featurizer_path = '/home/cxw/sonos_rirs/features/testrun/featurizer.pickle'
with open(featurizer_path, 'rb') as f:
    featurizer_load = pickle.load(f)

# %%
test_feat = block_f.process(y)
load_feat = featurizer_load.process(y)

# %%
np.all(test_feat==load_feat)
# Out:
# True
